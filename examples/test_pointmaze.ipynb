# %%
import ogbench
import numpy as np

env = ogbench.make_env_and_datasets(
    'pointmaze-medium-navigate-singletask-task1-v0',
    env_only=True,
)

print('Observation space:', env.observation_space)
print('Action space:    ', env.action_space)

obs, info = env.reset(options=dict(task_id=1))
print(f'obs shape: {obs.shape}')
print(f'obs values: {obs}')
print()
print('goal shape:', info['goal'].shape)
print('goal values:', info['goal'])

# Check the underlying MuJoCo state
unwrapped = env.unwrapped
qpos = unwrapped.data.qpos.copy()
qvel = unwrapped.data.qvel.copy()
print(f'\nqpos (nq={len(qpos)}): {qpos}')
print(f'qvel (nv={len(qvel)}): {qvel}')

print('\n--- Comparing obs dims to qpos/qvel ---')
for i, v in enumerate(obs):
    print(f'  obs[{i}] = {v:.6f}')
# Out:
# Observation space: Box(-inf, inf, (2,), float64)
# Action space:     Box(-1.0, 1.0, (2,), float32)
# obs shape: (2,)
# obs values: [-0.74907606  0.33373095]
#
# goal shape: (2,)
# goal values: [20. 20.]
#
# qpos (nq=2): [-0.74907606  0.33373095]
# qvel (nv=2): [0.15450103 0.21439798]
#
# --- Comparing obs dims to qpos/qvel ---
#   obs[0] = -0.749076
#   obs[1] = 0.333731

# %%
for i in range(25):
    step = env.step(np.array([-0.1, 0.0]))
    print(step)
# Out:
# (array([-0.72976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.72976376, -0.59780676]), 'prev_qpos': array([-0.70976376, -0.59780676]), 'prev_qvel': array([0.06533921, 0.08793118]), 'qpos': array([-0.72976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.74976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.74976376, -0.59780676]), 'prev_qpos': array([-0.72976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.74976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.76976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.76976376, -0.59780676]), 'prev_qpos': array([-0.74976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.76976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.78976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.78976376, -0.59780676]), 'prev_qpos': array([-0.76976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.78976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.80976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.80976376, -0.59780676]), 'prev_qpos': array([-0.78976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.80976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.82976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.82976376, -0.59780676]), 'prev_qpos': array([-0.80976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.82976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.84976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.84976376, -0.59780676]), 'prev_qpos': array([-0.82976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.84976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.86976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.86976376, -0.59780676]), 'prev_qpos': array([-0.84976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.86976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.88976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.88976376, -0.59780676]), 'prev_qpos': array([-0.86976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.88976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.90976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.90976376, -0.59780676]), 'prev_qpos': array([-0.88976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.90976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.92976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.92976376, -0.59780676]), 'prev_qpos': array([-0.90976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.92976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.94976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.94976376, -0.59780676]), 'prev_qpos': array([-0.92976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.94976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.96976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.96976376, -0.59780676]), 'prev_qpos': array([-0.94976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.96976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-0.98976376, -0.59780676]), -1.0, False, False, {'xy': array([-0.98976376, -0.59780676]), 'prev_qpos': array([-0.96976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-0.98976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.00976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.00976376, -0.59780676]), 'prev_qpos': array([-0.98976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.00976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.02976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.02976376, -0.59780676]), 'prev_qpos': array([-1.00976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.02976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.04976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.04976376, -0.59780676]), 'prev_qpos': array([-1.02976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.04976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.06976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.06976376, -0.59780676]), 'prev_qpos': array([-1.04976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.06976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.08976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.08976376, -0.59780676]), 'prev_qpos': array([-1.06976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.08976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.10976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.10976376, -0.59780676]), 'prev_qpos': array([-1.08976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.10976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.12976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.12976376, -0.59780676]), 'prev_qpos': array([-1.10976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.12976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.14976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.14976376, -0.59780676]), 'prev_qpos': array([-1.12976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.14976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.16976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.16976376, -0.59780676]), 'prev_qpos': array([-1.14976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.16976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.18976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.18976376, -0.59780676]), 'prev_qpos': array([-1.16976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.18976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})
# (array([-1.20976376, -0.59780676]), -1.0, False, False, {'xy': array([-1.20976376, -0.59780676]), 'prev_qpos': array([-1.18976376, -0.59780676]), 'prev_qvel': array([0., 0.]), 'qpos': array([-1.20976376, -0.59780676]), 'qvel': array([0., 0.]), 'success': 0.0})

# %%
type(env.unwrapped.data.qvel), env.unwrapped.data.qvel.shape
# Out:
# (numpy.ndarray, (2,))
